# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span><ul class="toc-item"><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Ход-исследования" data-toc-modified-id="Ход-исследования-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Ход исследования</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Первичное-изучение-данных" data-toc-modified-id="Первичное-изучение-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Первичное изучение данных</a></span></li><li><span><a href="#Проверка-формулы-вычисления-эффективного-обогащения" data-toc-modified-id="Проверка-формулы-вычисления-эффективного-обогащения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка формулы вычисления эффективного обогащения</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование-изменения-концентрации-элементов-на-каждом-этапе" data-toc-modified-id="Исследование-изменения-концентрации-элементов-на-каждом-этапе-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследование изменения концентрации элементов на каждом этапе</a></span></li><li><span><a href="#Анализ-распределения-размеров-гранул-на-выборках" data-toc-modified-id="Анализ-распределения-размеров-гранул-на-выборках-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ распределения размеров гранул на выборках</a></span></li><li><span><a href="#Расчёт-суммарных-концентраций" data-toc-modified-id="Расчёт-суммарных-концентраций-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Расчёт суммарных концентраций</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Вычисление-итогового-sMAPE" data-toc-modified-id="Вычисление-итогового-sMAPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вычисление итогового sMAPE</a></span></li><li><span><a href="#Обучение-моделей,-выбор-лучшей" data-toc-modified-id="Обучение-моделей,-выбор-лучшей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучение моделей, выбор лучшей</a></span><ul class="toc-item"><li><span><a href="#Масштабирование-данных" data-toc-modified-id="Масштабирование-данных-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Масштабирование данных</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Итог,-оценка-моделей" data-toc-modified-id="Итог,-оценка-моделей-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Итог, оценка моделей</a></span></li></ul></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# ## Введение

# %% [markdown]
# Требуется подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используем данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Необходимо:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# ### Технологический процесс

# %% [markdown]
# Изучим внимательно стадии процесса.
#
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
# <img src="https://pictures.s3.yandex.net/resources/viruchka_1576238830.jpg" width="75%">
#
# 1. **Флотация**
#
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# 2. **Очистка**
#
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
# **Описание данных**
#
# **Технологический процесс**
#
#     Rougher feed — исходное сырье
#     Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#         Xanthate **— ксантогенат (промотер, или активатор флотации);
#         Sulphate — сульфат (на данном производстве сульфид натрия);
#         Depressant — депрессант (силикат натрия).
#     Rougher process (англ. «грубый процесс») — флотация
#     Rougher tails — отвальные хвосты
#     Float banks — флотационная установка
#     Cleaner process — очистка
#     Rougher Au — черновой концентрат золота
#     Final Au — финальный концентрат золота
#
# **Параметры этапов**
#
#     air amount — объём воздуха
#     fluid levels — уровень жидкости
#     feed size — размер гранул сырья
#     feed rate — скорость подачи
#
# **Наименование признаков**
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
#
# **Возможные значения для блока [этап]:**
#
#     rougher — флотация
#     primary_cleaner — первичная очистка
#     secondary_cleaner — вторичная очистка
#     final — финальные характеристики
#
# **Возможные значения для блока [тип_параметра]:**
#
#     input — параметры сырья
#     output — параметры продукта
#     state — параметры, характеризующие текущее состояние этапа
#     calculation — расчётные характеристики
#
# **Расчёт эффективности**
#
# Нам нужно смоделировать процесс восстановления золота из золотосодержащей руды.
#
# Эффективность обогащения рассчитывается по формуле
#
# <img src="https://pictures.s3.yandex.net/resources/Recovery_1576238822.jpg"  width="75%">
#
# где:
#
#     C — доля золота в концентрате после флотации/очистки;
#     F — доля золота в сырье/концентрате до флотации/очистки;
#     T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.
#
# **Метрика качества**
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# Нужно спрогнозировать сразу две величины:
#
#     эффективность обогащения чернового концентрата rougher.output.recovery;
#     эффективность обогащения финального концентрата final.output.recovery.

# %% [markdown]
# ### Ход исследования

# %% [markdown]
# **1. Подготовка данных**
#
# Путь к файлам:
# - /datasets/gold_recovery_train_new.csv
# - /datasets/gold_recovery_test_new.csv
# - /datasets/gold_recovery_full_new.csv
#
# 1.2. Проверить, что эффективность обогащения рассчитана правильно. Вычислить её на обучающей выборке для признака rougher.output.recovery. Найти MAE между  расчётами и значением признака. Описать выводы.
#
# 1.3. Проанализировать признаки, недоступные в тестовой выборке.
#
# 1.4. Провести предобработку данных.
#
# **2. Проанализировать данные**
#
# 2.1. Посмотреть, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки
#
# 2.2. Сравнить распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#
# 2.3. Исследовать суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
# **3. Построение модели**
#
# 3.1. Написать функцию для вычисления итоговой sMAPE.
#
# 3.2. Обучить разные модели и оцените их качество кросс-валидацией. Выбрать лучшую модель и проверить её на тестовой выборке.

# %% [markdown]
# ## Подготовка данных

# %%
# Импорты

import pandas as pd
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('/datasets/gold_recovery_full_new.csv')
train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
test = pd.read_csv('/datasets/gold_recovery_test_new.csv')

# %% [markdown]
# ### Первичное изучение данных

# %%
df.sample(10)
# Out:
#                       date  final.output.concentrate_ag  \
# 1637   2016-04-02 07:00:00                     5.814818
# 9928   2017-05-04 10:59:59                     4.118744
# 19344  2018-08-14 07:59:59                     4.183103
# 15403  2018-02-02 12:59:59                     5.751913
# 12583  2017-09-13 01:59:59                     4.169992
# 8104   2017-02-10 19:59:59                     6.068545
# 1374   2016-03-18 23:00:00                     2.598985
# 2022   2016-05-02 02:59:59                     6.426878
# 17391  2018-05-07 15:59:59                     4.728920
# 18201  2018-06-14 07:59:59                     4.162842
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 1637                     10.841625                      9.615898
# 9928                     11.304232                      8.976509
# 19344                     7.271436                      9.147700
# 15403                    10.021247                      8.297532
# ...

# %%
train.shape
# Out:
# (14149, 87)

# %%
test.shape
# Out:
# (5290, 53)

# %%
df.shape
# Out:
# (19439, 87)

# %% [markdown]
# Так как таблица слишком большая даже для поверхностного изучения, рассмотрим информацию о датафреймах и описание значений.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
test.hist(bins=20, figsize=(20,20));

# %%
print(test['date'].head(10))
print(test['date'].tail(10))
# Out:
# 0    2016-09-01 00:59:59
# 1    2016-09-01 01:59:59
# 2    2016-09-01 02:59:59
# 3    2016-09-01 03:59:59
# 4    2016-09-01 04:59:59
# 5    2016-09-01 05:59:59
# 6    2016-09-01 06:59:59
# 7    2016-09-01 07:59:59
# 8    2016-09-01 08:59:59
# 9    2016-09-01 09:59:59
# Name: date, dtype: object
# 5280    2017-12-31 14:59:59
# 5281    2017-12-31 15:59:59
# 5282    2017-12-31 16:59:59
# 5283    2017-12-31 17:59:59
# 5284    2017-12-31 18:59:59
# 5285    2017-12-31 19:59:59
# 5286    2017-12-31 20:59:59
# 5287    2017-12-31 21:59:59
# 5288    2017-12-31 22:59:59
# 5289    2017-12-31 23:59:59
# Name: date, dtype: object

# %% [markdown]
# Проверим сильно коррелирующие между собой признаки.

# %%
test.corr()
# Out:
#                                             primary_cleaner.input.sulfate  \
# primary_cleaner.input.sulfate                                    1.000000
# primary_cleaner.input.depressant                                 0.455718
# primary_cleaner.input.feed_size                                  0.114456
# primary_cleaner.input.xanthate                                   0.497568
# primary_cleaner.state.floatbank8_a_air                           0.102653
# primary_cleaner.state.floatbank8_a_level                         0.048032
# primary_cleaner.state.floatbank8_b_air                           0.075737
# primary_cleaner.state.floatbank8_b_level                         0.138949
# primary_cleaner.state.floatbank8_c_air                           0.024710
# primary_cleaner.state.floatbank8_c_level                         0.027697
# primary_cleaner.state.floatbank8_d_air                           0.095001
# primary_cleaner.state.floatbank8_d_level                        -0.020533
# ...

# %% [markdown]
# ### Проверка формулы вычисления эффективного обогащения

# %% [markdown]
# Перед возможным изменением данных в результате предобработки проверим правильность формулы вычисления эффективного обогащения.

# %% [markdown]
# Эффективность обогащения:
#
# <img src="https://pictures.s3.yandex.net/resources/Recovery_1576238822.jpg" width="75%">
#
# где:
# - C — доля золота в концентрате после флотации/очистки, [rougher.output.concentrate_au], [final.output.concentrate_au];
# - F — доля золота в сырье/концентрате до флотации/очистки [rougher.input.feed_au] *(считается от начала обогащения, а не от начала этапа)*;
# - T — доля золота в отвальных хвостах после флотации/очистки [rougher.output.tail_au], [final.output.tail_au].

# %%
def rec_calc(C, F, T):
    recovery = (C * (F - T))/(F * (C - T))*100
    return recovery

# %%
# Так как будем добавлять дополнительный столбец, запишем датафрейм в отдельную переменную, чтобы не запутать модель

df_0 = train
df_0['recovery_float'] = rec_calc(df_0['rougher.output.concentrate_au'], df_0['rougher.input.feed_au'], df_0['rougher.output.tail_au'])
df_0['recovery_final'] = rec_calc(df_0['final.output.concentrate_au'], df_0['rougher.input.feed_au'], df_0['final.output.tail_au'])

# %%
# Сравниваем расчёт с данными в предоставленном датафрейме

df_0[['recovery_float', 'rougher.output.recovery']].sample(7)
# Out:
#        recovery_float  rougher.output.recovery
# 6004        97.060963                97.060963
# 11583       94.290744                94.290744
# 13563       88.964459                88.964459
# 13650       90.307447                90.307447
# 8814        72.953240                72.953240
# 9093        74.084879                74.084879
# 12851       89.573380                89.573380

# %%
# Сравним все значения
# Округляем дополнительно, так как при расчётах округлённые значения могут не совпадать в последнем знаке
# из-за различной специфики округления

print(f"MAE, rough: {mean_absolute_error(df_0['recovery_float'].round(5), df_0['rougher.output.recovery'].round(5))}")
print(f"MAE, final: {mean_absolute_error(df_0['recovery_final'].round(5), df_0['final.output.recovery'].round(5))}")
# Out:
# MAE, rough: 0.0
# MAE, final: 0.0

# %% [markdown]
# Отклонения равны нулю. Это говорит о том, что расчёты верны.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Заполним пропуски методом интерполяции. Так как процесс протекает непрерывно, такое заполнение будет наиболее корректным.

# %%
df = df.interpolate()
train = train.interpolate()
test = test.interpolate()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 89 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14149 non-null  float64
#  2   final.output.concentrate_pb                         14149 non-null  float64
#  3   final.output.concentrate_sol                        14149 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14149 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5290 non-null   float64
#  2   primary_cleaner.input.depressant            5290 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %% [markdown]
# Имеются пропуски в разных столбцах в разном количестве. Также в тестовой выборке меньше столбцов, чем в обучающей. Рассмотрим отсутствующие столбцы.

# %%
dif_cols = []
for i in range(len(df.columns)):
    if df.columns[i] not in test.columns:
        dif_cols.append(df.columns[i])
        print(df.columns[i])
# Out:
# final.output.concentrate_ag
# final.output.concentrate_pb
# final.output.concentrate_sol
# final.output.concentrate_au
# final.output.recovery
# final.output.tail_ag
# final.output.tail_pb
# final.output.tail_sol
# final.output.tail_au
# primary_cleaner.output.concentrate_ag
# primary_cleaner.output.concentrate_pb
# primary_cleaner.output.concentrate_sol
# primary_cleaner.output.concentrate_au
# primary_cleaner.output.tail_ag
# primary_cleaner.output.tail_pb
# primary_cleaner.output.tail_sol
# primary_cleaner.output.tail_au
# rougher.calculation.sulfate_to_au_concentrate
# rougher.calculation.floatbank10_sulfate_to_au_feed
# rougher.calculation.floatbank11_sulfate_to_au_feed
# rougher.calculation.au_pb_ratio
# rougher.output.concentrate_ag
# rougher.output.concentrate_pb
# rougher.output.concentrate_sol
# rougher.output.concentrate_au
# rougher.output.recovery
# rougher.output.tail_ag
# rougher.output.tail_pb
# rougher.output.tail_sol
# rougher.output.tail_au
# ...

# %% [markdown]
# По списку признаков видно, что в тестовой выборке отсутствуют столбцы с расчётными данными и output-параметры продукта. Эти параметры не являются основой для предсказания концентрации золота, а могут быть следствием этого предсказания, то есть для целевого признака удалённые признаки являются утечкой.
#
# Удалим эти признаки из обучающей выборки, но предварительно запишем rougher.output.recovery и final.output.recovery отдельно, так как они являются целевыми.
#
# По значениям в таблице видно, что в одних и тех же флотационных установках одни параметры в разных точках, эти значения очень сильно коррелируют между собой. Разницу между этими значениями можно считать флуктуацией. Заменим эти столбцы на средние значения для каждой флотационной установки.

# %%
# Список наименований столбцов для удобства

test.columns
# Out:
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
# ...

# %%
# параллельно уберём лишние точки для корректной работы .query()

train['primary_cleaner_state_floatbank8_air'] = train[['primary_cleaner.state.floatbank8_a_air',
                                                      'primary_cleaner.state.floatbank8_b_air',
                                                      'primary_cleaner.state.floatbank8_c_air',
                                                      'primary_cleaner.state.floatbank8_d_air']].mean(axis=1)

test['primary_cleaner_state_floatbank8_air'] = test[['primary_cleaner.state.floatbank8_a_air',
                                                      'primary_cleaner.state.floatbank8_b_air',
                                                      'primary_cleaner.state.floatbank8_c_air',
                                                      'primary_cleaner.state.floatbank8_d_air']].mean(axis=1)


train['rougher_state_floatbank10_air'] = train[['rougher.state.floatbank10_a_air',
                                                'rougher.state.floatbank10_b_air',
                                                'rougher.state.floatbank10_c_air',
                                                'rougher.state.floatbank10_d_air',
                                                'rougher.state.floatbank10_e_air',
                                                'rougher.state.floatbank10_f_air']].mean(axis=1)

test['rougher_state_floatbank10_air'] = test[['rougher.state.floatbank10_a_air',
                                              'rougher.state.floatbank10_b_air',
                                              'rougher.state.floatbank10_c_air',
                                              'rougher.state.floatbank10_d_air',
                                              'rougher.state.floatbank10_e_air',
                                              'rougher.state.floatbank10_f_air']].mean(axis=1)

train['rougher_state_floatbank10_level'] = train[['rougher.state.floatbank10_a_level',
                                                  'rougher.state.floatbank10_b_level',
                                                  'rougher.state.floatbank10_c_level',
                                                  'rougher.state.floatbank10_d_level',
                                                  'rougher.state.floatbank10_e_level',
                                                  'rougher.state.floatbank10_f_level']].mean(axis=1)

test['rougher_state_floatbank10_level'] = test[['rougher.state.floatbank10_a_level',
                                                'rougher.state.floatbank10_b_level',
                                                'rougher.state.floatbank10_c_level',
                                                'rougher.state.floatbank10_d_level',
                                                'rougher.state.floatbank10_e_level',
                                                'rougher.state.floatbank10_f_level']].mean(axis=1)

train['secondary_cleaner_state_floatbank2_air'] = train[['secondary_cleaner.state.floatbank2_a_air',
                                                         'secondary_cleaner.state.floatbank2_b_air']].mean(axis=1)

test['secondary_cleaner_state_floatbank2_air'] = test[['secondary_cleaner.state.floatbank2_a_air',
                                                       'secondary_cleaner.state.floatbank2_b_air']].mean(axis=1)

train['secondary_cleaner_state_floatbank3_air'] = train[['secondary_cleaner.state.floatbank3_a_air',
                                                         'secondary_cleaner.state.floatbank3_b_air']].mean(axis=1)

test['secondary_cleaner_state_floatbank3_air'] = test[['secondary_cleaner.state.floatbank3_a_air',
                                                       'secondary_cleaner.state.floatbank3_b_air']].mean(axis=1)

train['secondary_cleaner_state_floatbank4_air'] = train[['secondary_cleaner.state.floatbank4_a_air',
                                                         'secondary_cleaner.state.floatbank4_b_air']].mean(axis=1)

test['secondary_cleaner_state_floatbank4_air'] = test[['secondary_cleaner.state.floatbank4_a_air',
                                                       'secondary_cleaner.state.floatbank4_b_air']].mean(axis=1)

train['secondary_cleaner_state_floatbank5_air'] = train[['secondary_cleaner.state.floatbank5_a_air',
                                                         'secondary_cleaner.state.floatbank5_b_air']].mean(axis=1)

test['secondary_cleaner_state_floatbank5_air'] = test[['secondary_cleaner.state.floatbank5_a_air',
                                                       'secondary_cleaner.state.floatbank5_b_air']].mean(axis=1)

train['secondary_cleaner_state_floatbank6_air'] = train[['secondary_cleaner.state.floatbank6_a_air']].mean(axis=1)

test['secondary_cleaner_state_floatbank6_air'] = test[['secondary_cleaner.state.floatbank6_a_air']].mean(axis=1)


train['secondary_cleaner_state_floatbank2_level'] = train[['secondary_cleaner.state.floatbank2_a_level',
                                                         'secondary_cleaner.state.floatbank2_b_level']].mean(axis=1)

test['secondary_cleaner_state_floatbank2_level'] = test[['secondary_cleaner.state.floatbank2_a_level',
                                                       'secondary_cleaner.state.floatbank2_b_level']].mean(axis=1)

train['secondary_cleaner_state_floatbank3_level'] = train[['secondary_cleaner.state.floatbank3_a_level',
                                                         'secondary_cleaner.state.floatbank3_b_level']].mean(axis=1)

test['secondary_cleaner_state_floatbank3_level'] = test[['secondary_cleaner.state.floatbank3_a_level',
                                                       'secondary_cleaner.state.floatbank3_b_level']].mean(axis=1)

train['secondary_cleaner_state_floatbank4_level'] = train[['secondary_cleaner.state.floatbank4_a_level',
                                                         'secondary_cleaner.state.floatbank4_b_level']].mean(axis=1)

test['secondary_cleaner_state_floatbank4_level'] = test[['secondary_cleaner.state.floatbank4_a_level',
                                                       'secondary_cleaner.state.floatbank4_b_level']].mean(axis=1)

train['secondary_cleaner_state_floatbank5_level'] = train[['secondary_cleaner.state.floatbank5_a_level',
                                                         'secondary_cleaner.state.floatbank5_b_level']].mean(axis=1)

test['secondary_cleaner_state_floatbank5_level'] = test[['secondary_cleaner.state.floatbank5_a_level',
                                                       'secondary_cleaner.state.floatbank5_b_level']].mean(axis=1)

train['secondary_cleaner_state_floatbank6_level'] = train[['secondary_cleaner.state.floatbank6_a_level']].mean(axis=1)

test['secondary_cleaner_state_floatbank6_level'] = test[['secondary_cleaner.state.floatbank6_a_level']].mean(axis=1)

# %%
# На будущее уберём точки из некоторых других важных наименований столбцов

train = train.rename(columns={'rougher.output.recovery': 'rougher_output_recovery',
                             'final.output.recovery': 'final_output_recovery',
                              'rougher.input.feed_size': 'rougher_input_feed_size',
                           'primary_cleaner.input.feed_size': 'primary_cleaner_input_feed_size'})
test = test.rename(columns={'rougher.output.recovery': 'rougher_output_recovery',
                             'final.output.recovery': 'final_output_recovery',
                           'rougher.input.feed_size': 'rougher_input_feed_size',
                           'primary_cleaner.input.feed_size': 'primary_cleaner_input_feed_size'})

# %%
# Начальные данные удалим
columns_to_delete = ['primary_cleaner.state.floatbank8_a_air',
       'primary_cleaner.state.floatbank8_a_level',
       'primary_cleaner.state.floatbank8_b_air',
       'primary_cleaner.state.floatbank8_b_level',
       'primary_cleaner.state.floatbank8_c_air',
       'primary_cleaner.state.floatbank8_c_level',
       'primary_cleaner.state.floatbank8_d_air',
       'primary_cleaner.state.floatbank8_d_level',
       'rougher.state.floatbank10_a_air',
       'rougher.state.floatbank10_a_level',
       'rougher.state.floatbank10_b_air',
       'rougher.state.floatbank10_b_level',
       'rougher.state.floatbank10_c_air',
       'rougher.state.floatbank10_c_level',
       'rougher.state.floatbank10_d_air',
       'rougher.state.floatbank10_d_level',
       'rougher.state.floatbank10_e_air',
       'rougher.state.floatbank10_e_level',
       'rougher.state.floatbank10_f_air',
       'rougher.state.floatbank10_f_level',
       'secondary_cleaner.state.floatbank2_a_air',
       'secondary_cleaner.state.floatbank2_a_level',
       'secondary_cleaner.state.floatbank2_b_air',
       'secondary_cleaner.state.floatbank2_b_level',
       'secondary_cleaner.state.floatbank3_a_air',
       'secondary_cleaner.state.floatbank3_a_level',
       'secondary_cleaner.state.floatbank3_b_air',
       'secondary_cleaner.state.floatbank3_b_level',
       'secondary_cleaner.state.floatbank4_a_air',
       'secondary_cleaner.state.floatbank4_a_level',
       'secondary_cleaner.state.floatbank4_b_air',
       'secondary_cleaner.state.floatbank4_b_level',
       'secondary_cleaner.state.floatbank5_a_air',
       'secondary_cleaner.state.floatbank5_a_level',
       'secondary_cleaner.state.floatbank5_b_air',
       'secondary_cleaner.state.floatbank5_b_level',
       'secondary_cleaner.state.floatbank6_a_air',
       'secondary_cleaner.state.floatbank6_a_level']

# %% [markdown]
# Допустим, процесс не сезонный и не зависит от времени суток, поэтому для построения модели столбец с датой применять нельзя, заодно удалим ненужные столбцы.

# %%
train = train.drop(columns=columns_to_delete)
test = test.drop(columns=columns_to_delete)

# %% [markdown]
# Ранее на графиках мы наблюдали неравномерное распределение некоторых величин, рассмотрим подробнее.

# %%
test.hist(bins=50,figsize=(16, 16));

# %% [markdown]
# Такие признаки, как из группы feed_size и значения уровня флотационной установки, имеют чёткие области концентрации и выбросы. Избавимся от выбросов. Предполагаем, что выбросы возникают при неосновных операциях на оборудовании: оборудование простаивает, чистка датчиков, ППР и т.п. Так как объекты записывались в датафрейм непрерывно, такие ситуации могли быть зарегистрированы.

# %%
train['rougher_input_feed_size'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
train = train.query('rougher_input_feed_size < 105')
test = test.query('rougher_input_feed_size < 105')

# %%
train['primary_cleaner_input_feed_size'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
train = train.query('primary_cleaner_input_feed_size > 6')
test = test.query('primary_cleaner_input_feed_size > 6')

# %% [markdown]
# Рассмотрим выбросы в целевом признаке:

# %%
train['rougher_output_recovery'].hist(bins=100);

# %%
train['final_output_recovery'].hist(bins=100);

# %% [markdown]
# Имеются пики на нулевых значениях. Очистим датафрейм от значений меньше 60 для флотации и меньше 35 для очистки.

# %%
train = train.query('rougher_output_recovery > 60 & final_output_recovery > 35 & final_output_recovery < 90')

# %% [markdown]
# Так как нам необходимо предсказать коэффициент восстановления золота на разных этапах, разобьём датафрейм на две части - до получения чернового концентрата, где будем предсказывать содержание в черновом концентрате, и после - с предсказанием финальной концентрации. Так как в наименовании столбца первым словом кодируется блок технологического этапа, используем это для сортировки признаков:

# %%
# По первой (нулевой) букве сортируем имена столбцов

rougher_cols = []
final_cols = []
for col in range(len(test.columns)):
    if test.columns[col][0] == 'r':
        rougher_cols.append(test.columns[col])
        final_cols.append(test.columns[col])
    else:
        final_cols.append(test.columns[col])

# %%
# Проверяем

rougher_cols
# Out:
# ['rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher_input_feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher_state_floatbank10_air',
#  'rougher_state_floatbank10_level']

# %%
# Сохраняем датафреймы с признаками, используя списки названий столбцов

train_features_rougher = train[rougher_cols]
train_features_final = train[final_cols]
test_features_rougher = test[rougher_cols]
test_features_final = test[final_cols]

# %%
# Объявляем столбец с датами как индекс

test = test.set_index('date')
df = df.set_index('date')

# %%
test
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
# 2016-09-01 03:59:59                     215.336236
# 2016-09-01 04:59:59                     199.099327
# ...                                            ...
# 2017-12-31 19:59:59                     173.957757
# 2017-12-31 20:59:59                     172.910270
# 2017-12-31 21:59:59                     171.135718
# 2017-12-31 22:59:59                     179.697158
# 2017-12-31 23:59:59                     181.556856
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
# 2016-09-01 03:59:59                         12.006805
# 2016-09-01 04:59:59                         10.682530
# ...

# %%
train_target_rougher = train['rougher_output_recovery']
train_target_final = train['final_output_recovery']

test_target_rougher = df.loc[test.index,'rougher.output.recovery']
test_target_final = df.loc[test.index,'final.output.recovery']

# %%
train_features_final
# Out:
#                       date  primary_cleaner.input.sulfate  \
# 0      2016-01-15 00:00:00                     127.092003
# 1      2016-01-15 01:00:00                     125.629232
# 2      2016-01-15 02:00:00                     123.819808
# 3      2016-01-15 03:00:00                     122.270188
# 4      2016-01-15 04:00:00                     117.988169
# ...                    ...                            ...
# 14141  2018-08-18 03:59:59                     125.423263
# 14142  2018-08-18 04:59:59                     114.108530
# 14143  2018-08-18 05:59:59                     119.497545
# 14144  2018-08-18 06:59:59                     123.381787
# 14148  2018-08-18 10:59:59                      95.248427
#
#        primary_cleaner.input.depressant  primary_cleaner_input_feed_size  \
# 0                             10.128295                             7.25
# 1                             10.296251                             7.25
# ...

# %%
train_features_final = train_features_final.drop(columns='date')
test_features_final = test_features_final.drop(columns='date')

#test_target_rougher = test_target_rougher.drop(test_target_rougher.columns[0], axis=1)
#test_target_final = test_target_final.drop(test_target_rougher.columns[0], axis=1)

# %%
test_target_rougher = test_target_rougher.reset_index(drop=True).values
test_target_final = test_target_final.reset_index(drop=True).values

# %%
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %% [markdown]
# ### Вывод
#
# 1. Изучили данные с параметрами и результатами технологического процесса за 2016-2018 неполные годы;
# 2. Заполнили пропуски в обучающей выборке методом интерполяции;
# 3. Разделили датафреймы в зависимости на "до" и "после" получения чернового концентрата;
# 4. Очистили датафрейм от выбросов;
# 5. Проверили расчёт эффективности обогащения, расчёт верный.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследование изменения концентрации элементов на каждом этапе

# %% [markdown]
# Изучим изменение концентрации золота, серебра и свинца на различных этапах очистки.

# %%
# Cлишком длинные названия признаков, сделаем функцию, чтобы не печатать их дважды на строке

# Так как мы сочетаем разные графики на одном холсте, важно иметь одинаковую ширину столбиков
#, иначе высота графиков будет различаться, что даст ложные представления о данных

def biner(col):
    bins = range(int(min(col)), int(max(col)))
    return bins

# %%
# Золото

plt.figure(figsize=(15, 8))

plt.hist(df['rougher.input.feed_au'], bins=biner(df['rougher.input.feed_au']), label='rougher.input', color='#906B04', alpha=0.5)
plt.hist(df['rougher.output.concentrate_au'], bins=biner(df['rougher.output.concentrate_au']), label='rougher.output', color='#E6C619', alpha=0.5)
plt.hist(df['primary_cleaner.output.concentrate_au'], bins=biner(df['primary_cleaner.output.concentrate_au']), label='primary_cleaner.output', color='#FFD700', alpha=0.5)
plt.hist(df['final.output.concentrate_au'], bins=biner(df['final.output.concentrate_au']), label='final.output', color='#FFED00', alpha=0.7)

plt.title('Распределение результатов измерений концентрации золота на различных этапах процесса')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=4)
plt.show()

# %% [markdown]
# Концентрация золота расномерно растёт в ходе каждого этапа очистки. Рассмотрим содержание серебра в материале:

# %%
# Серебро

plt.figure(figsize=(15, 8))

plt.hist(df['rougher.input.feed_ag'], bins=biner(df['rougher.input.feed_ag']), label='rougher.input', color='#000000', alpha=0.5, histtype='step')
plt.hist(df['rougher.output.concentrate_ag'], bins=biner(df['rougher.output.concentrate_ag']), label='rougher.output', color='#909090', alpha=0.5, histtype='stepfilled')
plt.hist(df['primary_cleaner.output.concentrate_ag'], bins=biner(df['primary_cleaner.output.concentrate_ag']), label='primary_cleaner.output', color='#C0C0C0', alpha=0.5, histtype='stepfilled')
plt.hist(df['final.output.concentrate_ag'], bins=biner(df['final.output.concentrate_ag']), label='final.output', color='#e0e0e0', alpha=0.5, histtype='stepfilled')

plt.title('Распределение измерений концентрации серебра на различных этапах процесса')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=4)
plt.show()

# %% [markdown]
# Количество серебра снижается в ходе обработки, но после флотации в черновом концентрате серебра больше, чем в руде. Если учесть, что данные достоверны, физически снижение концентрации можно объяснить двумя способами:
# 1. Масса серебра неизменна, но растёт масса рабочего материала;
# 2. Серебро удаляется в "хвосты".
#
# Так как схеме соответствует второй пункт, проверим содержание серебра в "хвостах".

# %%
# Серебро в "хвостах"

plt.figure(figsize=(15, 8))

plt.hist(df['rougher.input.feed_ag'], bins=biner(df['rougher.input.feed_ag']), label='rougher.input', color='#000000', alpha=0.5, histtype='step')
plt.hist(df['rougher.output.tail_ag'], bins=biner(df['rougher.output.tail_ag']), label='rougher.output', color='#909090', alpha=0.5, histtype='stepfilled')
plt.hist(df['secondary_cleaner.output.tail_ag'], bins=biner(df['secondary_cleaner.output.tail_ag']), label='secondary_cleaner.output', color='#C0C0C0', alpha=0.5, histtype='stepfilled')
plt.hist(df['final.output.tail_ag'], bins=biner(df['final.output.tail_ag']), label='final.output', color='#e0e0e0', alpha=0.5, histtype='stepfilled')

plt.title('Распределение измерений концентрации серебра в хвостах на различных этапах процесса')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=4)
plt.show()

# %% [markdown]
# Действительно, серебро частично удаляется вместе с хвостами, особенно во время очистки.

# %%
# Свинец

plt.figure(figsize=(15, 8))

plt.hist(df['rougher.input.feed_pb'], bins=biner(df['rougher.input.feed_pb']), label='rougher.input', color='#000000', alpha=0.5, histtype='step')
plt.hist(df['rougher.output.concentrate_pb'], bins=biner(df['rougher.output.concentrate_pb']), label='rougher.output', color='#809080', alpha=0.5, histtype='stepfilled')
plt.hist(df['primary_cleaner.output.concentrate_pb'], bins=biner(df['primary_cleaner.output.concentrate_pb']), label='primary_cleaner.output', color='#B0C0B0', alpha=0.5, histtype='stepfilled')
plt.hist(df['final.output.concentrate_pb'], bins=biner(df['final.output.concentrate_pb']), label='final.output', color='#D0E0D0', alpha=0.5, histtype='stepfilled')

plt.title('Распределение измерений концентрации свинца на различных этапах процесса')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=4)
plt.show()

# %% [markdown]
# Содержание свинца  резко вырастает после флотации, затем растёт после первого этапа очистки. Содержание свинца в итоговом материале примерно равно концентрации после первой очистки.

# %% [markdown]
# ### Анализ распределения размеров гранул на выборках

# %% [markdown]
# Рассмотрим распределение размеров гранул на обучающей и тестовой выборках. Если разница будет существенная, обучение модели может быть неправильным.

# %%
plt.figure(figsize=(15, 8))

plt.hist(train['rougher_input_feed_size'], bins=biner(df['rougher.input.feed_size']), label='train', alpha=0.5)
plt.hist(test['rougher_input_feed_size'], bins=biner(df['rougher.input.feed_size']), label='test', alpha=0.5)

plt.title('Распределение размеров гранул до флотации на выборках')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=2)
plt.show()

# %% [markdown]
# На графиках имеется две области концентрации, но на тестовой выборке эти области смещены влево. Ранее мы выяснили, что в тестовой выборке затронуты месяцы с сентября по декабрь включительно, а в обучающей выборке - остальные. Предполагаем, что отклонение в размерах гранул связано с сезоном: зимой используют сырьё из других регионов, срабатывают остатки и т.д. Некоторые <a href="https://ferronordic.ru/press-center/operating_experience/sekret-uspekha-starateley-na-zolotykh-priiskakh-/" target="_blank">источники</a> действительно подтверждают, что золотодобыча - сезонное дело, поэтому наиболее свежее сырьё попало в тренировочную выборку.
#
# Проверим критичность, изучив данные о размере гранул после флотации.

# %%
plt.figure(figsize=(15, 8))

plt.hist(train['primary_cleaner_input_feed_size'], bins=40, label='train', alpha=0.5)
plt.hist(test['primary_cleaner_input_feed_size'], bins=36, label='test', alpha=0.5)

plt.title('Распределение размеров гранул после флотации на выборках')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=2)
plt.show()

# %% [markdown]
# После флотации распределения выравниваются и похожи на нормальное.
#
# Выравнивание данных после флотации дополнительно подтверждает правильность разбиения датафрейма на две части - признаки до чернового концентрата не влияют на процессы после чернового концентрата, поэтому для прогнозирования `final.output.recovery` не требуются.

# %% [markdown]
# ### Расчёт суммарных концентраций

# %% [markdown]
# Рассмотрим общую концентрацию металлов в материале на разных этапах технологического процесса.

# %%
# Используем датафрейм с дополнительными расчётами

df_0['raw_sum'] = df_0['rougher.input.feed_au'] + df_0['rougher.input.feed_pb'] + df_0['rougher.input.feed_ag']
df_0['rough_sum'] = df_0['rougher.output.concentrate_au'] + df_0['rougher.output.concentrate_pb'] + df_0['rougher.output.concentrate_ag']
df_0['final_sum'] = df_0['final.output.concentrate_au'] + df_0['final.output.concentrate_pb'] + df_0['final.output.concentrate_ag']

plt.figure(figsize=(15, 8))
plt.hist(df_0['raw_sum'], bins=biner(df_0['raw_sum']), label='raw', color='#809080', alpha=0.8)
plt.hist(df_0['rough_sum'], bins=biner(df_0['rough_sum']), label='rough', color='#B0C0B0', alpha=0.8)
plt.hist(df_0['final_sum'], bins=biner(df_0['final_sum']), label='final', color='#D0E0D0', alpha=0.8)

plt.title('Распределение измерений концентрации металлов в материале')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=3)
plt.show()

# %%
df_0['raw_sum'] = df_0['rougher.input.feed_au'] + df_0['rougher.input.feed_pb'] + df_0['rougher.input.feed_ag'] + df_0['rougher.input.feed_sol']
df_0['rough_sum'] = df_0['rougher.output.concentrate_au'] + df_0['rougher.output.concentrate_pb'] + df_0['rougher.output.concentrate_ag'] + df_0['rougher.output.concentrate_sol']
df_0['final_sum'] = df_0['final.output.concentrate_au'] + df_0['final.output.concentrate_pb'] + df_0['final.output.concentrate_ag'] + df_0['final.output.concentrate_sol']

plt.figure(figsize=(15, 8))
plt.hist(df_0['raw_sum'], bins=biner(df_0['raw_sum']), label='raw', color='#809080', alpha=0.8)
plt.hist(df_0['rough_sum'], bins=biner(df_0['rough_sum']), label='rough', color='#B0C0B0', alpha=0.8)
plt.hist(df_0['final_sum'], bins=biner(df_0['final_sum']), label='final', color='#D0E0D0', alpha=0.8)

plt.title('Распределение измерений концентрации всех веществ в материале')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=3)
plt.show()

# %% [markdown]
# Концентрация металлов растёт по мере очистки руды, что соответствует начальной задумке.
# Концентрация всех веществ растёт после флотации, но после очистки, в среднем не изменяется, но снижается дисперсия концентраций.
#
# Также наблюдаем область концентрации значений при нуле. Рассмотрим строки с нулевой суммой подробнее:

# %%
df_0.query('final_sum == 0').head(10)
# Out:
#                      date  final.output.concentrate_ag  \
# 644   2016-02-13 11:00:00                          0.0
# 1193  2016-03-11 10:00:00                          0.0
# 1194  2016-03-11 11:00:00                          0.0
# 1195  2016-03-11 12:00:00                          0.0
# 1196  2016-03-11 13:00:00                          0.0
# 1682  2016-04-09 17:00:00                          0.0
# 2019  2016-05-01 23:59:59                          0.0
# 2020  2016-05-02 00:59:59                          0.0
# 2236  2016-05-11 01:59:59                          0.0
# 3394  2016-07-06 04:59:59                          0.0
#
#       final.output.concentrate_pb  final.output.concentrate_sol  \
# 644                           0.0                           0.0
# 1193                          0.0                           0.0
# 1194                          0.0                           0.0
# 1195                          0.0                           0.0
# ...

# %%
df_0.query('rough_sum == 0').head(10)
# Out:
#                      date  final.output.concentrate_ag  \
# 45    2016-01-16 21:00:00                     4.566664
# 46    2016-01-16 22:00:00                     4.577832
# 47    2016-01-16 23:00:00                     4.591462
# 48    2016-01-17 00:00:00                     5.296830
# 49    2016-01-17 02:00:00                     8.162896
# 50    2016-01-17 03:00:00                     5.759800
# 51    2016-01-17 04:00:00                     5.807253
# 759   2016-02-18 20:00:00                     8.478624
# 1243  2016-03-13 12:00:00                     0.371783
# 1682  2016-04-09 17:00:00                     0.000000
#
#       final.output.concentrate_pb  final.output.concentrate_sol  \
# 45                      10.406178                      4.588698
# 46                      10.691605                      5.274175
# 47                      10.628846                      5.688961
# 48                      10.597469                           NaN
# ...

# %% [markdown]
# Часто нулевые значения записаны подряд. Такое в действительности возможно, если материал отсутствует для измерения: простои, поломки, тех.обслуживание оборудования, модернизация, изменение параметров и т.д. Данные были бы более нереалистичными, если бы оборудование работало бесперебойно в течение трёх лет.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Провели исследование изменения концентраций металлов на различных стадиях технологического процесса. Содержание золота постепенно растёт после каждой стадии очистки. Количество серебра в основном материале увеличичается после флотации затем снижается, так как серебро частично удаляется вместе с "хвостами". Содержание свинца также выше, чем в руде.
# 2. Изучили распределение размеров гранул на выборках. В тестовой выборке размер гранул в среднем меньше, что может подтверждать зависимость от сезона. В дальнейшем это может помешать построению качественной модели.
# 3. Провели расчёт суммарных концентраций металлов. Содержание металлов в материале растёт по мере очистки.

# %% [markdown]
# ## Построение модели

# %% [markdown]
# ### Вычисление итогового sMAPE

# %% [markdown]
# Создадим функцию для расчёта sMAPE. Формула выглядит следующим образом:

# %% [markdown]
# <img src="https://pictures.s3.yandex.net/resources/smape_1576239058.jpg" width="70%">
# <img src="https://pictures.s3.yandex.net/resources/_smape_1576239054.jpg" width="70%">

# %%
def smape_calc(target_v, predicted_v):
    n = len(target_v)
    smape_v = (1 / n) * np.sum(abs(target_v - predicted_v) / ((abs(target_v) + abs(predicted_v)) / 2)) * 100
    return smape_v

def total_smape_calc(smape_rougher, smape_final):
    total_smape = 0.25 * smape_rougher + 0.75 * smape_final
    return total_smape

# %% [markdown]
# Так как sMAPE является уникальной для предприятия метрикой, сохраним её для дальнейшего расчёта эффективности модели.

# %%
smape_score = make_scorer(score_func=smape_calc, greater_is_better=0)

# %% [markdown]
# ### Обучение моделей, выбор лучшей

# %% [markdown]
# Так как перед нами стоит задача предсказать целевой параметр, применим модели регрессии для поиска наиболее эффективной. В качестве метрики качества примем sMAPE.

# %%
### Создадим функцию для вывода результата кросс-валидации

def cross_val(mod, feat, targ):
    scores = cross_val_score(mod, feat, targ, cv=3)
    final_score = sum(scores) / len(scores)
    print('Средняя оценка качества модели:', final_score)

# %% [markdown]
# #### Масштабирование данных

# %%
scaler = MinMaxScaler()
scaler.fit(train_features_rougher)

train_features_rougher = scaler.transform(train_features_rougher)
test_features_rougher = scaler.transform(test_features_rougher)

# %%
scaler = MinMaxScaler()
scaler.fit(train_features_final)

train_features_final = scaler.transform(train_features_final)
test_features_final = scaler.transform(test_features_final)

# %% [markdown]
# #### Линейная регрессия

# %% [markdown]
# Оценим модель линейной регрессии кросс-валидацией

# %%
# new
model_rougher_lr = LinearRegression().fit(train_features_rougher, train_target_rougher)
scores_rougher_lr = cross_val_score(model_rougher_lr, train_features_rougher, train_target_rougher, cv=4, scoring=smape_score)
print("Средняя оценка качества модели:", scores_rougher_lr.mean())
scores_rougher_lr
# Out:
# Средняя оценка качества модели: -6.585695836732711
# array([-8.61638489, -5.11053872, -5.0892765 , -7.52658323])

# %%
# new
model_final_lr = LinearRegression().fit(train_features_final, train_target_final)
scores_final_lr = cross_val_score(model_final_lr, train_features_final, train_target_final, cv=4, scoring=smape_score)
print("Средняя оценка качества модели:", scores_final_lr.mean())
scores_final_lr
# Out:
# Средняя оценка качества модели: -9.01301560677124
# array([ -8.79492902,  -7.87712234,  -8.21532452, -11.16468655])

# %% [markdown]
# Построим модель линейной регрессии для предсказания

# %%
model_rougher_lr = LinearRegression()
model_rougher_lr.fit(train_features_rougher, train_target_rougher)
predicted_rougher_lr = model_rougher_lr.predict(test_features_rougher)
smape_r_lr = smape_calc(test_target_rougher, predicted_rougher_lr)
print('sMAPE, rougher =', smape_r_lr)
# Out:
# sMAPE, rougher = 8.203423208058023

# %%
model_final_lr = LinearRegression()
model_final_lr.fit(train_features_final, train_target_final)
predicted_final_lr = model_final_lr.predict(test_features_final)
smape_f_lr = smape_calc(test_target_final, predicted_final_lr)
print('sMAPE, final =', smape_f_lr)
# Out:
# sMAPE, final = 8.81380174926018

# %%
total_smape_calc(smape_r_lr, smape_f_lr)
# Out:
# 8.661207113959641

# %% [markdown]
# Проверим качество моделей:

# %%
print('RMSE, rougher:', mean_squared_error(test_target_rougher, predicted_rougher_lr) ** 0.5)
print('RMSE, final:', mean_squared_error(test_target_final, predicted_final_lr) ** 0.5)
print('-' * 40)
print('R2, rougher:', r2_score(test_target_rougher, predicted_rougher_lr))
print('R2, final:', r2_score(test_target_final, predicted_final_lr))
# Out:
# RMSE, rougher: 12.79316031159777
# RMSE, final: 8.851712696015094
# ----------------------------------------
# R2, rougher: 0.054575470195860065
# R2, final: 0.056948262480695844

# %% [markdown]
# #### Дерево решений

# %%
# new
model_rougher_dtr = DecisionTreeRegressor().fit(train_features_rougher, train_target_rougher)
scores_rougher_dtr = cross_val_score(model_rougher_dtr, train_features_rougher, train_target_rougher, cv=4, scoring=smape_score)
print("Средняя оценка качества модели:", scores_rougher_dtr.mean())
scores_rougher_dtr
# Out:
# Средняя оценка качества модели: -8.412382733936864
# array([-11.70652294,  -8.66833717,  -5.65630283,  -7.61836799])

# %%
# new
model_final_dtr = DecisionTreeRegressor().fit(train_features_final, train_target_final)
scores_final_dtr = cross_val_score(model_final_dtr, train_features_rougher, train_target_final, cv=4, scoring=smape_score)
print("Средняя оценка качества модели:", scores_final_dtr.mean())
scores_final_dtr
# Out:
# Средняя оценка качества модели: -13.788447390326498
# array([-15.55018914, -12.81724209, -13.30076212, -13.48559621])

# %% [markdown]
# Качество модели хуже, чем у линейной регрессии. Рассмотрим модель случайного леса.

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# Для случайного леса проверим sMAPE, используя GridSearchCV.

# %%
rfr_null = RandomForestRegressor()
rfr_null.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rfr_params = {'max_depth': range (1, 10),
              'n_estimators': range (20, 21), # Сокращено для экономии времени исполнения кода
              'random_state': [999]}

# %% [markdown]
# Подберём гиперпараметры:

# %%
rfr_grid = GridSearchCV(rfr_null, rfr_params, scoring=smape_score, cv=5)
rfr_grid.fit(train_features_rougher, train_target_rougher)
predict_grid = rfr_grid.predict(test_features_rougher)
print('Гиперпараметры:', rfr_grid.best_params_)
print('nMSE:',rfr_grid.best_score_)
smape_rfr_grid_r = smape_calc(test_target_rougher, predict_grid)
print('sMAPE:', smape_rfr_grid_r)
# Out:
# Гиперпараметры: {'max_depth': 5, 'n_estimators': 20, 'random_state': 999}
# nMSE: -5.940229344971815
# sMAPE: 8.204926350100386

# %% [markdown]
# Создадим модель с полученными гиперпараметрами:

# %%
model_rougher_rfr = RandomForestRegressor(random_state=999, max_depth=5, n_estimators=29)
model_rougher_rfr.fit(train_features_rougher, train_target_rougher)
predicted_rougher_rfr = model_rougher_rfr.predict(test_features_rougher)
smape_rfr_r = smape_calc(test_target_rougher, predicted_rougher_rfr)
print('sMAPE, rougher =', smape_rfr_r)
# Out:
# sMAPE, rougher = 8.190681780710417

# %% [markdown]
# Аналогично найдём гиперпараметры для модели, работающей с этапом очистки.

# %%
rfr_grid = GridSearchCV(rfr_null, rfr_params, scoring=smape_score, cv=3)
rfr_grid.fit(train_features_final, train_target_final)
predict_grid = rfr_grid.predict(test_features_final)
print('Гиперпараметры:', rfr_grid.best_params_)
print('nMSE:',rfr_grid.best_score_)
smape_rfr_grid_r = smape_calc(test_target_final, predict_grid)
print('sMAPE:', smape_rfr_grid_r)
# Out:
# Гиперпараметры: {'max_depth': 1, 'n_estimators': 20, 'random_state': 999}
# nMSE: -8.737595730368389
# sMAPE: 9.094556780488547

# %%
model_final_rfr = RandomForestRegressor(random_state=999, max_depth=1, n_estimators=29)
model_final_rfr.fit(train_features_final, train_target_final)
predicted_final_rfr = model_final_rfr.predict(test_features_final)
smape_rfr_f = smape_calc(test_target_final, predicted_final_rfr)
print('sMAPE, final =', smape_rfr_f)
# Out:
# sMAPE, final = 9.103907532252785

# %%
print('Итоговое sMAPE:', total_smape_calc(smape_rfr_r, smape_rfr_f))
# Out:
# Итоговое sMAPE: 8.875601094367195

# %%
print('Rougher train:')
print(cross_val(model_rougher_rfr, train_features_rougher, train_target_rougher))
print('Final train:')
print(cross_val(model_final_rfr, train_features_final, train_target_final))
# Out:
# Rougher train:
# Средняя оценка качества модели: -1.445972786201925
# None
# Final train:
# Средняя оценка качества модели: -0.06881913054215823
# None

# %%
print('Rougher test:')
print(cross_val(model_rougher_rfr, test_features_rougher, test_target_rougher))
print('Final test:')
print(cross_val(model_final_rfr, test_features_final, test_target_final))
# Out:
# Rougher test:
# Средняя оценка качества модели: -5.460710465330401
# None
# Final test:
# Средняя оценка качества модели: 0.025044553999324887
# None

# %% [markdown]
# #### Итог, оценка моделей

# %% [markdown]
# Наименьший показатель sMAPE - 21.06, результат работы модели линейной регрессии. Качество модели - неудовлетворительное. Сравним работу модели с заполнением константным значением.

# %%
test_rougher_const = pd.Series([test_target_rougher.mean()]*len(test_target_rougher))
test_final_const = pd.Series([test_target_final.mean()]*len(test_target_final))

# %%
predicted_rougher_lr_const = model_rougher_lr.predict(test_features_rougher)
smape_lr_r_const = smape_calc(test_rougher_const, predicted_rougher_lr_const)
print('sMAPE, const, rougher =', smape_lr_r_const)
# Out:
# sMAPE, const, rougher = 3.9643771686869256

# %%
predicted_final_lr_const = model_final_lr.predict(test_features_final)
smape_lr_f_const = smape_calc(test_final_const, predicted_final_lr_const)
print('sMAPE, const, final =', smape_lr_f_const)
# Out:
# sMAPE, const, final = 5.300937898478306

# %%
print('sMAPE, const, total:', total_smape_calc(smape_lr_r_const, smape_lr_f_const))
# Out:
# sMAPE, const, total: 4.966797716030461

# %% [markdown]
# Сравним с константной моделью случайного леса.

# %%
predicted_rougher_rfr_const = model_rougher_rfr.predict(test_features_rougher)
smape_rfr_r_const = smape_calc(test_rougher_const, predicted_rougher_rfr_const)
print('sMAPE, const, rougher =', smape_rfr_r_const)
# Out:
# sMAPE, const, rougher = 3.2284239180641396

# %%
predicted_final_rfr_const = model_final_rfr.predict(test_features_final)
smape_rfr_f_const = smape_calc(test_final_const, predicted_final_rfr_const)
print('sMAPE, final =', smape_rfr_f_const)
# Out:
# sMAPE, final = 4.319071174308867

# %%
print('sMAPE, const, total:', total_smape_calc(smape_rfr_r_const, smape_rfr_f_const))
# Out:
# sMAPE, const, total: 4.046409360247685

# %% [markdown]
# Качество константной модели гораздо выше, чем у модели машинного обучения.

# %% [markdown]
# ## Вывод

# %% [markdown]
# 1. Изучили данные, предоставленные компанией "Цифра" для прогнозирования эффективности восстановления золота из золотосодержашей руды.
# 2. Провели предобработку данных:
#     - очистили данные от выбросов;
#     - очистили данные от неактуальных для обучения объектов;
#     - объединили однородные признаки в средние.
# 3. Провели исследование изменения концентраций металлов на различных стадиях технологического процесса. Выявили зависимость содержания металлов от стадии в основном материале и "хвостах".
# 4. Построили модели машинного обучения для прогнозирования коэффициента восстановления золота из руды. Так как процесс разбит на два этапа, флотацию и очистку, построили две модели. Лучший показатель sMAPE достигнут в модели случайного леса - 21,06, но результат работы модели неудовлетворителен по причине низкого качества. При анализе данных выявили различия в размере гранул у тестовой и обучающей выборки, что могло повлиять на корректность модели. Важно учесть, что пропуски в данных были заполнены методом интерполяции. Удаление пропусков также приведёт к повышению качества модели, но так как пропуски возможны в дальнейшем, модель работает с предположительными данными.
